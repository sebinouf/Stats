# %%
from moviepy.video.io.bindings import mplfig_to_npimage
import moviepy.editor as mpy
import mayavi.mlab as mlab
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline


###Video params
fps=20.
t_tot=7    ##time in secondes
nbt = t_tot * fps
dt = 1.

t_mean = t_tot/2.

tab_phi = np.linspace(0, 2*np.pi, 100)
Rmax = 100
Rmin=20

Nb_points  =100

rand_phi = np.random.rand(Nb_points)*np.pi*2
rand_r = np.random.rand(Nb_points)
rand_r[0] = 0. ###fixe un point central
tab_dx = rand_r*np.cos(rand_phi)
tab_dy = rand_r*np.sin(rand_phi)


#tab_dx = (np.random.rand(Nb_points)-0.5)*2.
#tab_dy = (np.random.rand(Nb_points)-0.5)*2.

fig_mpl, ax= plt.subplots(1,figsize=(20,20), facecolor='white')
ax.plot(Rmin*np.cos(tab_phi),Rmin*np.sin(tab_phi), color='lightgreen', linewidth=4 )
ax.plot(Rmin*tab_dx, Rmin*tab_dy, 'o', color='blue')


ax.set_xlim( (-Rmax, Rmax) )
ax.set_ylim( (-Rmax, Rmax) )
ax.axes.get_xaxis().set_visible(False)
ax.axes.get_yaxis().set_visible(False)
ax.set_axis_off()

alpha_max = 0.3   #Transparency factor for the plot
alpha_min = 0.05

def make_frame_mpl(t):
    ax.clear()

    
    Rt = Rmin+ (Rmax-Rmin)/(1.*t_tot)*(t_mean-abs(t-t_mean))*2

    alpha_Rt = alpha_max - (alpha_max - alpha_min)*(Rt - Rmin)/(Rmax - Rmin)
    ax.set_xlim( (-Rmax, Rmax) )
    ax.set_ylim( (-Rmax, Rmax) )
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.fill(Rt*np.cos(tab_phi), Rt*np.sin(tab_phi), color='red', alpha=alpha_Rt)
    ax.plot(Rt*np.cos(tab_phi),Rt*np.sin(tab_phi), color='lightgreen', linewidth=4 )
    ax.plot(Rt*tab_dx, Rt*tab_dy, 'o', color='blue')
    ax.set_axis_off()
    
    return mplfig_to_npimage(fig_mpl) # RGB image of the figure

animation = mpy.VideoClip(make_frame_mpl, duration=nbt/fps)
animation.write_gif("Expansion.gif", fps=fps)
# Out:
# [MoviePy] Building file Expansion.gif with imageio
#  99%|█████████▉| 140/141 [00:18<00:00,  8.07it/s]

# %%
from moviepy.video.io.bindings import mplfig_to_npimage
import moviepy.editor as mpy
import mayavi.mlab as mlab
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline


###Video params
fps=20.
t_tot=10    ##time in secondes
nbt = t_tot * fps
dt = 1.

t_mean= t_tot/2.

tab_phi = np.linspace(0, 2*np.pi, 100)
Rmax = 100
Rmin=20

Nb_points  =500

#rand_phi = np.random.rand(Nb_points)*np.pi*2
#rand_r = np.random.rand(Nb_points)*Rmax*1./Rmin
#rand_r[0] = 0. ###fixe un point central
#tab_dx = rand_r*np.cos(rand_phi)
#tab_dy = rand_r*np.sin(rand_phi)


tab_dx = (np.random.rand(Nb_points)-0.5)*2.*Rmax*1./Rmin
tab_dy = (np.random.rand(Nb_points)-0.5)*2.*Rmax*1./Rmin

fig_mpl, ax= plt.subplots(1,figsize=(20,20), facecolor='white')
#ax.plot(Rmin*np.cos(tab_phi),Rmin*np.sin(tab_phi), color='lightgreen', linewidth=4 )
ax.plot(Rmin*tab_dx, Rmin*tab_dy, 'o', color='blue')

ax.set_xlim( (-Rmax, Rmax) )
ax.set_ylim( (-Rmax, Rmax) )
ax.axes.get_xaxis().set_visible(False)
ax.axes.get_yaxis().set_visible(False)

alpha_max = 0.3   #Transparency factor for the plot
alpha_min = 0.05


def make_frame_mpl(t):
    ax.clear()

    
    #Rt = Rmin+ (Rmax-Rmin)/(1.*t_tot)*t
    Rt = Rmin + 3*(t_mean - abs(t-t_mean))
    max_Rt = Rmin + 3*t_mean
    alpha_Rt = alpha_max - (alpha_max - alpha_min)*(Rt - Rmin)/(max_Rt - Rmin)
    #print alpha_Rt
    
    ax.set_xlim( (-Rmax, Rmax) )
    ax.set_ylim( (-Rmax, Rmax) )
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    #ax.plot(Rt*np.cos(tab_phi),Rt*np.sin(tab_phi), color='lightgreen', linewidth=4 )
    ax.fill_between([-Rmax, Rmax], -Rmax, Rmax, color='red', alpha=alpha_Rt)
    ax.plot(Rt*tab_dx, Rt*tab_dy, 'o', color='blue')
    ax.set_axis_off()
    
    return mplfig_to_npimage(fig_mpl) # RGB image of the figure

animation = mpy.VideoClip(make_frame_mpl, duration=nbt/fps)
animation.write_gif("Expansion_no_cercle_color.gif", fps=fps)
# Out:
# [MoviePy] Building file Expansion_no_cercle_color.gif with imageio
# 100%|█████████▉| 200/201 [00:29<00:00,  6.73it/s]

# %%
from moviepy.video.io.bindings import mplfig_to_npimage
import moviepy.editor as mpy
import mayavi.mlab as mlab
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline


tab_phi = np.linspace(0, 2*np.pi, 100)


plt.plot(np.cos(tab_phi), np.sin(tab_phi))
plt.fill(np.cos(tab_phi), np.sin(tab_phi), color='red', alpha=0.2)

print -9/4
# Out:
# -3
